# %%
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyAQ3QulDwae740d738AFGaAM70Ikel-HPg')

from urllib.request import urlopen
from bs4 import BeautifulSoup

import mysql.connector as mysql
import re
import time

# %%
def getLat(geocode):
    return geocode[0]['geometry']['location']['lat']

def getLng(geocode):
    return geocode[0]['geometry']['location']['lng']

# %%
def scrapePage(quote_page):
    page = urlopen(quote_page)
    soup = BeautifulSoup(page, 'html.parser')
    
    info_list = []

    # loops through each restaurant in page
    for elem in soup.select('.regular-search-result'):
        try:
            element = {}

            # get name
            for n in elem.select('.biz-name.js-analytics-click'):
                for span in n.select('span'):
                    element['name'] = span.text

            # get review
            for rev in elem.select('.review-count.rating-qualifier'):
                element['review'] = re.search(r'\d+', rev.text).group()

            # get rating
            for rt in elem.select('.biz-rating.biz-rating-large.clearfix'):
                for img in rt.select('img'):
                    ratingStr = img.get('alt')
                    element['rating'] = re.search(r'\d\.\d', ratingStr).group()
                    
            # get image
            img = elem.select_one("img")
            element['img'] = img['src']

            # get 'more info' link
            for l in elem.select(".biz-name.js-analytics-click"):
                element['link'] = "https://www.yelp.com" + l['href']

            # get categories as a list
            for f in elem.select('.category-str-list'):
                catList = []
                for a in f.find_all('a'):
                    catList.append(a.text)
                element['types'] = catList

            # get the address
            for a in elem.select('address'):
                for br in a.find_all('br'):
                    br.replace_with(", ")
                addr = a.text.strip()
                if "Vancouver" not in addr:
                    addr = addr + ", Vancouver BC"
                element['address'] = addr

                # get geocode
                geocode_result = gmaps.geocode(element['address'])
                element['lat'] = getLat(geocode_result)
                element['lon'] = getLng(geocode_result)

            info_list.append(element)
            print(element)
            
        except AttributeError: pass

    return info_list

# %%
import pickle

# Scraping data from Yelp webpage

quote_page = 'https://www.yelp.ca/search?find_desc=Restaurants&find_loc=Vancouver,+British+Columbia&start='
new_page = ''
start = 0
big_list = []

limit = 2300
total = 0

while (True):
    new_page = quote_page + str(start)
    page = scrapePage(new_page)
    total += len(page)
    
    if (len(page) == 0):
        break
    
    big_list.extend(page)
    
    print("Page: " + str(start // 10 + 1))
    start += 10
    time.sleep(10)
    
    if (total%100 == 0):
        pickle.dump(big_list, open("big_list.pickle", "wb"))
    
    if (total>limit):
        break
# Out:
# {'name': 'Tuc Craft Kitchen', 'review': '755', 'rating': '4.5', 'img': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZbTzB0MCGaKm_phC_esufQ/ls.jpg', 'link': 'https://www.yelp.com/biz/tuc-craft-kitchen-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Comfort Food', 'Bars'], 'address': '60 W Cordova Street, Vancouver BC', 'lat': 49.2826445, 'lon': -123.1060592}
# {'name': 'Fable', 'review': '584', 'rating': '4.5', 'img': 'https://s3-media3.fl.yelpcdn.com/bphoto/9A0iSEqXuKCEJgEHIuI2uw/ls.jpg', 'link': 'https://www.yelp.com/biz/fable-vancouver?osq=Restaurants', 'types': ['Canadian (New)'], 'address': '1944 W 4th Avenue, Vancouver BC', 'lat': 49.2679331, 'lon': -123.1490012}
# {'name': 'Guu with Garlic', 'review': '785', 'rating': '4.5', 'img': 'https://s3-media3.fl.yelpcdn.com/bphoto/-BqY7grkfFcVnE3TXuUuxA/ls.jpg', 'link': 'https://www.yelp.com/biz/guu-with-garlic-vancouver-2?osq=Restaurants', 'types': ['Japanese', 'Tapas Bars'], 'address': '1698 Robson Street, Vancouver BC', 'lat': 49.2902619, 'lon': -123.1338815}
# {'name': 'The Flying Pig - Yaletown', 'review': '889', 'rating': '4.0', 'img': 'https://s3-media1.fl.yelpcdn.com/bphoto/vsqRnjBzdXj-o2wBMF3HGw/ls.jpg', 'link': 'https://www.yelp.com/biz/the-flying-pig-yaletown-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Seafood'], 'address': '1168 Hamilton Street, Unit 104, Vancouver BC', 'lat': 49.2751066, 'lon': -123.1220961}
# {'name': 'Miku', 'review': '1162', 'rating': '4.5', 'img': 'https://s3-media3.fl.yelpcdn.com/bphoto/OBIHYzIe_0-RYJ8TjQ8CdQ/ls.jpg', 'link': 'https://www.yelp.com/biz/miku-vancouver-2?osq=Restaurants', 'types': ['Japanese', 'Sushi Bars'], 'address': '200 Granville Street, Suite 70, Vancouver BC', 'lat': 49.2867409, 'lon': -123.112267}
# {'name': 'Tavola', 'review': '293', 'rating': '4.5', 'img': 'https://s3-media1.fl.yelpcdn.com/bphoto/WR4Rt2BY1c5gYCerAXiwJg/ls.jpg', 'link': 'https://www.yelp.com/biz/tavola-vancouver?osq=Restaurants', 'types': ['Italian'], 'address': '1829 Robson Street, Vancouver BC', 'lat': 49.2919048, 'lon': -123.1356847}
# {'name': 'Forage', 'review': '476', 'rating': '4.0', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/ziBcgUjZkFVXVPpkO9aRLw/ls.jpg', 'link': 'https://www.yelp.com/biz/forage-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Breakfast & Brunch']}
# {'name': 'Blue Water Cafe', 'review': '734', 'rating': '4.5', 'img': 'https://s3-media1.fl.yelpcdn.com/bphoto/C-PwVUhZjOpGROt2IwUlpA/ls.jpg', 'link': 'https://www.yelp.com/biz/blue-water-cafe-vancouver?osq=Restaurants', 'types': ['Seafood', 'Live/Raw Food', 'Bars'], 'address': '1095 Hamilton St, Vancouver BC', 'lat': 49.276155, 'lon': -123.1211291}
# {'name': 'Nomad', 'review': '159', 'rating': '4.0', 'img': 'https://s3-media1.fl.yelpcdn.com/bphoto/uFH9YanDUUcl7BG531kLAg/ls.jpg', 'link': 'https://www.yelp.com/biz/nomad-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Comfort Food', 'Cocktail Bars'], 'address': '3950 Main Street, Vancouver BC', 'lat': 49.2498714, 'lon': -123.100783}
# {'name': 'The Flying Pig - Gastown', 'review': '678', 'rating': '4.0', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/abHdaoIdY0iRKEXULLO2kA/ls.jpg', 'link': 'https://www.yelp.com/biz/the-flying-pig-gastown-vancouver-2?osq=Restaurants', 'types': ['Canadian (New)', 'Seafood'], 'address': '102 Water Street, Vancouver BC', 'lat': 49.2837739, 'lon': -123.1067002}
# {'name': 'Escobar', 'review': '8', 'rating': '4.5', 'img': 'https://s3-media4.fl.yelpcdn.com/bphoto/jGxqO-L5kWn7Olu2yODY8w/ls.jpg', 'link': 'https://www.yelp.com/biz/escobar-vancouver-2?osq=Restaurants', 'types': ['Bars', 'Latin American'], 'address': '4245 Fraser Street, Vancouver BC', 'lat': 49.2471311, 'lon': -123.0904105}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\alex\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-6d3d3a82a11d> in <module>()
#      13 while (True):
#      14     new_page = quote_page + str(start)
# ---> 15     page = scrapePage(new_page)
#      16     total += len(page)
#      17
#
# <ipython-input-21-a0d26efd643a> in scrapePage(quote_page)
#      50
#      51                 # get geocode
# ---> 52                 geocode_result = gmaps.geocode(element['address'])
#      53                 element['lat'] = getLat(geocode_result)
#      54                 element['lon'] = getLng(geocode_result)
#
# C:\Users\alex\Anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# C:\Users\alex\Anaconda3\lib\site-packages\googlemaps\geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# C:\Users\alex\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     227         try:
#     228             response = requests_method(base_url + authed_url,
# --> 229                                        **final_requests_kwargs)
#     230         except requests.exceptions.Timeout:
#     231             raise googlemaps.exceptions.Timeout()
#
# C:\Users\alex\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# C:\Users\alex\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\Users\alex\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\Users\alex\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# C:\Users\alex\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# C:\Users\alex\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Users\alex\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\Users\alex\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\alex\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\alex\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\Users\alex\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# C:\Users\alex\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
### Append the rest of the data - start from page 78 ###

big_list = pickle.load(open("big_list.pickle", "rb"))
print(big_list)
# Out:
# [{'name': 'Tuc Craft Kitchen', 'review': '755', 'rating': '4.5', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZbTzB0MCGaKm_phC_esufQ/90s.jpg', 'link': 'https://www.yelp.com/biz/tuc-craft-kitchen-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Comfort Food', 'Bars'], 'address': '60 W Cordova Street, Vancouver, BC V6B 1C9', 'lat': 49.2826445, 'lon': -123.1060592}, {'name': 'Fable', 'review': '584', 'rating': '4.5', 'img': 'https://s3-media4.fl.yelpcdn.com/bphoto/9A0iSEqXuKCEJgEHIuI2uw/90s.jpg', 'link': 'https://www.yelp.com/biz/fable-vancouver?osq=Restaurants', 'types': ['Canadian (New)'], 'address': '1944 W 4th Avenue, Vancouver, BC V6J 1MS', 'lat': 49.2679601, 'lon': -123.1490085}, {'name': 'Guu with Garlic', 'review': '785', 'rating': '4.5', 'img': 'https://s3-media4.fl.yelpcdn.com/bphoto/-BqY7grkfFcVnE3TXuUuxA/90s.jpg', 'link': 'https://www.yelp.com/biz/guu-with-garlic-vancouver-2?osq=Restaurants', 'types': ['Japanese', 'Tapas Bars'], 'address': '1698 Robson Street, Vancouver, BC V6G 1C7', 'lat': 49.2902619, 'lon': -123.1338815}, {'name': 'The Flying Pig - Yaletown', 'review': '889', 'rating': '4.0', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/vsqRnjBzdXj-o2wBMF3HGw/90s.jpg', 'link': 'https://www.yelp.com/biz/the-flying-pig-yaletown-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Seafood'], 'address': '1168 Hamilton Street, Vancouver, BC V6B 2S2', 'lat': 49.2751066, 'lon': -123.1220961}, {'name': 'Miku', 'review': '1162', 'rating': '4.5', 'img': 'https://s3-media4.fl.yelpcdn.com/bphoto/OBIHYzIe_0-RYJ8TjQ8CdQ/90s.jpg', 'link': 'https://www.yelp.com/biz/miku-vancouver-2?osq=Restaurants', 'types': ['Japanese', 'Sushi Bars'], 'address': '200 Granville Street, Vancouver, BC V6C 1S4', 'lat': 49.28673360000001, 'lon': -123.1123927}, {'name': 'Tavola', 'review': '293', 'rating': '4.5', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/WR4Rt2BY1c5gYCerAXiwJg/90s.jpg', 'link': 'https://www.yelp.com/biz/tavola-vancouver?osq=Restaurants', 'types': ['Italian'], 'address': '1829 Robson Street, Vancouver, BC V6G 3E4', 'lat': 49.2919048, 'lon': -123.1356847}, {'name': 'Forage', 'review': '476', 'rating': '4.0', 'img': 'https://s3-media3.fl.yelpcdn.com/bphoto/ziBcgUjZkFVXVPpkO9aRLw/90s.jpg', 'link': 'https://www.yelp.com/biz/forage-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Breakfast & Brunch']}, {'name': 'Blue Water Cafe', 'review': '734', 'rating': '4.5', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/C-PwVUhZjOpGROt2IwUlpA/90s.jpg', 'link': 'https://www.yelp.com/biz/blue-water-cafe-vancouver?osq=Restaurants', 'types': ['Seafood', 'Live/Raw Food', 'Bars'], 'address': '1095 Hamilton St, Vancouver, BC V6B 5T4', 'lat': 49.276155, 'lon': -123.1211291}, {'name': 'Nomad', 'review': '159', 'rating': '4.0', 'img': 'https://s3-media2.fl.yelpcdn.com/bphoto/uFH9YanDUUcl7BG531kLAg/90s.jpg', 'link': 'https://www.yelp.com/biz/nomad-vancouver?osq=Restaurants', 'types': ['Canadian (New)', 'Comfort Food', 'Cocktail Bars'], 'address': '3950 Main Street, Vancouver, BC V5V 3P2', 'lat': 49.2498714, 'lon': -123.100783}, {'name': 'The Flying Pig - Gastown', 'review': '678', 'rating': '4.0', 'img': 'https://s3-media3.fl.yelpcdn.com/bphoto/abHdaoIdY0iRKEXULLO2kA/90s.jpg', 'link': 'https://www.yelp.com/biz/the-flying-pig-gastown-vancouver-2?osq=Restaurants', 'types': ['Canadian (New)', 'Seafood'], 'address': '102 Water Street, Vancouver, BC V6B 2K8', 'lat': 49.2837739, 'lon': -123.1067002}, {'name': 'Escobar', 'review': '8', 'rating': '4.5', 'img': 'https://s3-media1.fl.yelpcdn.com/bphoto/jGxqO-L5kWn7Olu2yODY8w/90s.jpg', 'link': 'https://www.yelp.com/biz/escobar-vancouver-2?osq=Restaurants', 'types': ['Bars', 'Latin American'], 'address': '4245 Fraser Street, Vancouver, BC V5V 4G1', 'lat': 49.2471311, 'lon': -123.0904105}, {'name': 'Guu Original Thurlow', 'review': '664', 'rating': '4.0', 'img': 'https://s3-media4.fl.yelpcdn.com/bphoto/gNwuwbneLP9FdvaYR2JbPg/90s.jpg', 'link': 'https://www.yelp.com/biz/guu-original-thurlow-vanco ...

# %%
# Putting all data into MySQL db

cnx = mysql.connect(user='root', database='webapp1')
cursor = cnx.cursor()

insert_elem = "INSERT INTO restaurantsvancouver (id, name, reviews, rating, address, latitude, longitude, image, link) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s);"
insert_type = "INSERT INTO categoriesvancouver (id, cat) VALUES (%s, %s);"

ID = 1
for i in big_list:
    #checks if there is elements without address, skips restaurant
    if 'address' not in i:
        continue
    
    #the data tuple to combine with the insert statement
    try:
        i_data = (ID, i['name'], i['review'], i['rating'], i['address'], i['lat'], i['lon'], i['img'], i['link'])
    except KeyError:
        i_data = (ID, i['name'], '0', '0', i['address'], i['lat'], i['lon'], i['img'], i['link'])
    
    #excecuting the combined query
    try:
        cursor.execute(insert_elem, i_data)
    except mysql.IntegrityError:
        pass
    
    #inserting data into the restaurant categories table
    for t in i['types']:
        t_data = (ID, t)
        cursor.execute(insert_type, t_data)
    
    ID += 1

cnx.commit() #committing everything to the db

cursor.close()
cnx.close()
